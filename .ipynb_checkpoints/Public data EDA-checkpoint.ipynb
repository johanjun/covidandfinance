# %% [markdown]
# # Data information
# - 코로나바이러스감염증-19(COVID-19) 현황 누적 데이터 (2021.01.28)
# - https://kdx.kr/data/view/25918

# %%
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# ## Covid19InfState.csv
#
# 1. seq : 고유값
# 2. stateDt : 기준일
# 3. stateTime : 기준시간
# 4. decideCnt : 확진자 수
# 5. clearCnt : 격리해제 수
# 6. examCnt : 검사진행 수
# 7. deathCnt : 사망자 수
# 8. careCnt : 치료중 환자 수
# 9. resultNegCnt : 결과 음성 수
# 10. accExamCnt : 누적 검사 수
# 11. accExamCompCnt : 누적 검사 완료 수
# 12. accDefRate : 누적 확진률
# 13. createDt : 등록일(시분초)
# 14. updateDt : 수정일(시분초)

# %%
df_state = pd.read_csv("data_public/Covid19InfState.csv")

# %%
df_state.shape
# Out:
# (399, 14)

# %%
df_state.head(50)
# Out:
#     seq   stateDt stateTime  decideCnt  clearCnt  examCnt  deathCnt  careCnt  \
# 0     1  20200101     18:00        NaN       1.0      1.0       NaN      NaN
# 1     2  20200202     09:00        2.0       2.0      2.0       2.0      NaN
# 2     3  20200203     09:00       15.0       NaN      NaN       NaN      NaN
# 3     4  20200204     00:00        NaN       NaN      NaN       NaN      NaN
# 4     5  20200205     09:00       18.0       NaN    129.0       NaN      NaN
# 5     6  20200205     19:00       19.0       1.0     40.0       NaN      NaN
# 6     7  20200206     09:00       23.0       1.0    169.0       NaN      NaN
# 7     8  20200207     09:00       24.0       2.0    264.0       NaN      NaN
# 8     9  20200207     16:00       24.0       2.0    327.0       NaN      NaN
# 9    10  20200208     09:00       24.0       2.0    620.0       NaN      NaN
# 10   11  20200208     16:00       24.0       2.0    939.0       NaN      NaN
# 11   12  20200208     16:00       24.0       2.0    939.0       NaN      NaN
# 12   13  20200208     16:00       24.0       2.0    939.0       NaN      NaN
# 13   14  20200208     16:00       24.0       2.0    939.0       NaN      NaN
# 14   15  20200209     09:00       25.0       3.0    960.0       NaN      NaN
# 15   16  20200209     16:00       27.0       3.0    888.0       NaN      NaN
# 16   17  20200210     09:00       27.0       3.0    809.0       NaN      NaN
# 17   18  20200210     16:00       27.0       3.0    531.0       NaN      NaN
# 18   19  20200211     09:00       28.0       4.0    865.0       NaN      NaN
# 19   20  20200211     16:00       28.0       4.0    762.0       NaN      NaN
# 20   21  20200212     09:00       28.0       4.0    992.0       NaN      NaN
# 21   22  20200212     16:00       28.0       7.0    785.0       NaN      NaN
# 22   23  20200213     09:00       28.0       7.0    670.0       NaN      NaN
# 23   24  20200213     16:00       28.0       7.0    562.0       NaN      NaN
# 24   25  20200214     09:00       28.0       7.0    692.0       NaN      NaN
# 25   26  20200214     16:00       28.0       7.0    535.0       NaN      NaN
# 26   27  20200215     09:00       28.0       7.0    638.0       NaN      NaN
# 27   28  20200215     16:00       28.0       9.0    558.0       NaN      NaN
# 28   29  20200216     09:00       29.0       9.0    577.0       NaN      NaN
# 29   30  20200216     16:00       29.0       9.0    485.0       NaN      NaN
# 30   31  20200217     09:00       30.0       9.0    408.0       NaN      NaN
# 31   32  20200217     16:00       30.0      10.0    708.0       NaN      NaN
# 32   33  20200218     09:00       31.0      10.0    957.0       NaN      NaN
# 33   34  20200218     09:00       31.0      10.0    957.0       NaN      NaN
# 34   35  20200218     16:00       31.0      12.0    818.0       NaN      NaN
# 35   36  20200219     09:00       46.0      12.0   1030.0       NaN      NaN
# 36   37  20200219     16:00       51.0      16.0   1149.0       NaN      NaN
# 37   38  20200220     09:00       82.0      16.0   1633.0       NaN      NaN
# 38   39  20200220     16:00      104.0      16.0   1860.0       1.0      NaN
# 39   40  20200221     09:00      156.0      16.0   2707.0       1.0      NaN
# 40   41  20200221     16:00      204.0      17.0   3180.0       1.0      NaN
# 41   42  20200221     16:00      204.0      17.0   3180.0       1.0      NaN
# 42   43  20200222     09:00      346.0      17.0   5481.0       2.0      NaN
# 43   44  20200222     16:00      433.0      18.0   6037.0       2.0      NaN
# 44   45  20200223     09:00      556.0      18.0   6039.0       4.0      NaN
# 45   46  20200223     16:00      602.0      18.0   8057.0       5.0      NaN
# 46   47  20200224     09:00      763.0      18.0   8725.0       7.0      NaN
# 47   48  20200224     16:00      833.0      22.0  11631.0       7.0      NaN
# 48   49  20200225     09:00      893.0      22.0  13273.0       8.0      NaN
# 49   50  20200225     16:00      977.0      22.0  13880.0      10.0      NaN
#
#     resutlNegCnt  accExamCnt  accExamCompCnt  accDefRate  \
# 0            NaN         NaN             NaN         NaN
# 1            NaN         NaN             NaN         NaN
# 2            NaN         NaN             NaN         NaN
# 3            NaN         NaN             NaN         NaN
# 4            NaN         NaN             NaN         NaN
# 5            NaN         NaN             NaN         NaN
# 6            NaN         NaN             NaN         NaN
# 7            NaN         NaN             NaN         NaN
# 8            NaN         NaN             NaN         NaN
# 9            NaN         NaN             NaN         NaN
# 10           NaN         NaN             NaN         NaN
# 11           NaN         NaN             NaN         NaN
# 12           NaN         NaN             NaN         NaN
# 13           NaN         NaN             NaN         NaN
# 14           NaN         NaN             NaN         NaN
# 15           NaN         NaN             NaN         NaN
# 16           NaN         NaN             NaN         NaN
# 17           NaN         NaN             NaN         NaN
# 18           NaN         NaN             NaN         NaN
# 19           NaN         NaN             NaN         NaN
# 20           NaN         NaN             NaN         NaN
# 21           NaN         NaN             NaN         NaN
# 22           NaN         NaN             NaN         NaN
# 23           NaN         NaN             NaN         NaN
# 24           NaN         NaN             NaN         NaN
# 25           NaN         NaN             NaN         NaN
# 26           NaN         NaN             NaN         NaN
# 27           NaN         NaN             NaN         NaN
# 28           NaN         NaN             NaN         NaN
# 29           NaN         NaN             NaN         NaN
# 30           NaN         NaN             NaN         NaN
# 31           NaN         NaN             NaN         NaN
# 32           NaN         NaN             NaN         NaN
# 33           NaN         NaN             NaN         NaN
# 34           NaN         NaN             NaN         NaN
# 35           NaN         NaN             NaN         NaN
# 36           NaN         NaN             NaN         NaN
# 37           NaN         NaN             NaN         NaN
# 38           NaN         NaN             NaN         NaN
# 39           NaN         NaN             NaN         NaN
# 40           NaN         NaN             NaN         NaN
# 41           NaN         NaN             NaN         NaN
# 42           NaN         NaN             NaN         NaN
# 43           NaN         NaN             NaN         NaN
# 44           NaN         NaN             NaN         NaN
# 45           NaN         NaN             NaN         NaN
# 46           NaN         NaN             NaN         NaN
# 47           NaN         NaN             NaN         NaN
# 48           NaN         NaN             NaN         NaN
# 49           NaN         NaN             NaN         NaN
#
# 352  2020-12-14 09:38:10.035                     NaN
# 353  2020-12-15 09:34:38.398                     NaN
# 354  2020-12-16 09:37:53.572                     NaN
# 355   2020-12-17 09:34:22.89                     NaN
# 356   2020-12-18 09:36:49.66                     NaN
# 357   2020-12-19 09:39:06.64                     NaN
# 358  2020-12-19 10:32:55.469                     NaN
# 359  2020-12-20 09:32:54.292                     NaN
# 360  2020-12-21 09:35:07.787                     NaN
# 361  2020-12-22 09:35:08.235                     NaN
# 362  2020-12-23 09:35:51.755                     NaN
# 363  2020-12-24 09:37:42.339                     NaN
# 364  2020-12-25 09:19:59.409                     NaN
# 365  2020-12-26 09:35:23.058                     NaN
# 366  2020-12-27 09:32:40.326                     NaN
# 367   2020-12-28 09:40:11.19                     NaN
# 368  2020-12-29 09:37:33.024                     NaN
# 369  2020-12-30 09:35:46.266                     NaN
# 370  2020-12-31 09:35:07.493                     NaN
# 371  2021-01-01 09:36:53.691                     NaN
# 372  2021-01-02 09:34:52.775                     NaN
# 373  2021-01-03 09:31:48.677                     NaN
# 374  2021-01-04 09:33:08.918                     NaN
# 375  2021-01-05 09:35:18.724                     NaN
# 376  2021-01-06 09:35:00.362                     NaN
# 377  2021-01-07 09:38:10.203                     NaN
# 378  2021-01-08 09:37:55.083                     NaN
# 379  2021-01-09 09:41:10.876                     NaN
# 380  2021-01-10 09:25:25.617                     NaN
# 381  2021-01-11 09:40:23.425                     NaN
# 382  2021-01-12 09:36:03.299                     NaN
# 383  2021-01-13 09:37:24.087                     NaN
# 384  2021-01-14 09:35:43.906                     NaN
# 385   2021-01-15 09:39:30.22                     NaN
# 386  2021-01-16 09:49:04.497                     NaN
# 387   2021-01-17 09:42:29.34                     NaN
# 388  2021-01-18 09:38:38.427                     NaN
# 389  2021-01-19 09:39:49.588                     NaN
# 390  2021-01-20 09:38:16.549                     NaN
# 391  2021-01-21 09:39:24.111                     NaN
# 392  2021-01-22 09:36:14.355                     NaN
# 393  2021-01-23 09:40:55.809  2021-01-23 10:29:19.08
# 394  2021-01-24 09:31:28.637                     NaN
# 395  2021-01-25 09:38:09.015                     NaN
# 396  2021-01-26 09:41:15.083                     NaN
# 397  2021-01-27 09:45:38.773                     NaN
# 398  2021-01-28 09:38:09.595                     NaN

# %% [markdown]
# - 확진자 수 X 기준일

# %%
df_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   seq             399 non-null    int64
#  1   stateDt         399 non-null    int64
#  2   stateTime       399 non-null    object
#  3   decideCnt       397 non-null    float64
#  4   clearCnt        396 non-null    float64
#  5   examCnt         397 non-null    float64
#  6   deathCnt        362 non-null    float64
#  7   careCnt         339 non-null    float64
#  8   resutlNegCnt    339 non-null    float64
#  9   accExamCnt      339 non-null    float64
#  10  accExamCompCnt  339 non-null    float64
#  11  accDefRate      339 non-null    float64
#  12  createDt        399 non-null    object
#  13  updateDt        26 non-null     object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 43.8+ KB

# %%
# 기준일을 datetime 데이터로 변환 (int -> str -> datetime)
import datetime
df_state.stateDt = df_state.stateDt.apply(lambda x:str(x)[:4]+'-'+str(x)[4:6]+'-'+str(x)[6:])
df_state.stateDt = df_state.stateDt.apply(lambda x:datetime.datetime.strptime(x, '%Y-%m-%d'))

# %%
df_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   seq             399 non-null    int64
#  1   stateDt         399 non-null    datetime64[ns]
#  2   stateTime       399 non-null    object
#  3   decideCnt       397 non-null    float64
#  4   clearCnt        396 non-null    float64
#  5   examCnt         397 non-null    float64
#  6   deathCnt        362 non-null    float64
#  7   careCnt         339 non-null    float64
#  8   resutlNegCnt    339 non-null    float64
#  9   accExamCnt      339 non-null    float64
#  10  accExamCompCnt  339 non-null    float64
#  11  accDefRate      339 non-null    float64
#  12  createDt        399 non-null    object
#  13  updateDt        26 non-null     object
# dtypes: datetime64[ns](1), float64(9), int64(1), object(3)
# memory usage: 43.8+ KB

# %%
#중복값 확인
df_state.duplicated

duplicate = df_state[df_state.duplicated()]
  
print("Duplicate Rows :")

duplicate
# Out:
# Duplicate Rows :
# Empty DataFrame
# Columns: [seq, stateDt, stateTime, decideCnt, clearCnt, examCnt, deathCnt, careCnt, resutlNegCnt, accExamCnt, accExamCompCnt, accDefRate, createDt, updateDt]
# Index: []

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# - 'decideCnt' 는 누적확진자임을 알 수 있음

# %%
fig, ax = plt.subplots(figsize=(16,8))
sns.histplot(x='stateDt', data=df_state, kde=True, bins=100, ax=ax)
# Out:
# <AxesSubplot:xlabel='stateDt', ylabel='Count'>

# %% [markdown]
# - 누적 말고 일별 확진자 추이를 보고싶은데..

# %%
stateDt_vc = df_state.stateDt.value_counts()

# %%
stateDt_vc.head(31)
# Out:
# 2020-02-08    5
# 2020-04-25    3
# 2020-02-18    3
# 2020-02-21    3
# 2020-02-19    2
# 2020-02-22    2
# 2020-02-07    2
# 2020-04-02    2
# 2020-02-12    2
# 2020-02-10    2
# 2020-02-27    2
# 2020-03-24    2
# 2020-02-24    2
# 2020-03-01    2
# 2020-02-20    2
# 2020-02-14    2
# 2020-02-17    2
# 2020-02-15    2
# 2020-12-08    2
# 2020-02-05    2
# 2020-02-11    2
# 2020-02-29    2
# 2020-02-26    2
# 2020-12-19    2
# 2020-02-25    2
# 2020-02-16    2
# 2020-02-23    2
# 2020-02-28    2
# 2020-02-13    2
# 2020-02-09    2
# 2020-07-14    1
# Name: stateDt, dtype: int64

# %%
df_stateDt_vc = pd.DataFrame(stateDt_vc)

# %%
df_stateDt_vc.head()
# Out:
#             stateDt
# 2020-02-08        5
# 2020-04-25        3
# 2020-02-18        3
# 2020-02-21        3
# 2020-02-19        2

# %% [markdown]
# - 중복으로 등록된 날들이 많아, 마지막 등록 시간을 제외하고는 삭제하자.

# %%
#중복 등록된 카운트가 1 초과인 경우를 추출하여 li로 등록
li = []
for i in range(len(df_stateDt_vc)):
    if df_stateDt_vc.iloc[i, 0] > 1:
        li.append(df_stateDt_vc.index[i])

# %%
len(li)
# Out:
# 30

# %%
#dt 변환
df_state.createDt = df_state.createDt.apply(lambda x:str(x))
df_state.createDt = df_state.createDt.apply(lambda x:datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S.%f'))

# %%
type(df_state.loc[0]['createDt'].hour)
# Out:
# int

# %%
df_state2 = df_state.set_index("stateDt")
df_state2.head()
# Out:
#             seq stateTime  decideCnt  clearCnt  examCnt  deathCnt  careCnt  \
# stateDt
# 2020-01-01    1     18:00        NaN       1.0      1.0       NaN      NaN
# 2020-02-02    2     09:00        2.0       2.0      2.0       2.0      NaN
# 2020-02-03    3     09:00       15.0       NaN      NaN       NaN      NaN
# 2020-02-04    4     00:00        NaN       NaN      NaN       NaN      NaN
# 2020-02-05    5     09:00       18.0       NaN    129.0       NaN      NaN
#
#             resutlNegCnt  accExamCnt  accExamCompCnt  accDefRate  \
# stateDt
# 2020-01-01           NaN         NaN             NaN         NaN
# 2020-02-02           NaN         NaN             NaN         NaN
# 2020-02-03           NaN         NaN             NaN         NaN
# 2020-02-04           NaN         NaN             NaN         NaN
# 2020-02-05           NaN         NaN             NaN         NaN
#
#                           createDt                updateDt
# stateDt
# 2020-01-01 2020-01-31 17:47:33.330  2020-02-03 12:21:56.56
# 2020-02-02 2020-02-03 12:22:49.490                     NaN
# 2020-02-03 2020-02-03 14:41:17.170  2020-02-04 14:19:46.46
# 2020-02-04 2020-02-03 21:26:59.590                     NaN
# 2020-02-05 2020-02-04 23:56:31.310   2020-02-05 9:43:16.16

# %%
#li 리스트에서 creatDt 시간이 17시 이전인 행들만 추출하여 sq에 seq 값을 저장
sq = []
for l in range(len(li)):
    for i in range(len(df_state2.loc[li[l]]['createDt'])):
        if df_state2.loc[li[l]]['createDt'][i].hour < 17:
            sq.append(df_state2.seq[df_state2['createDt'] == df_state2.loc[li[l]]['createDt'][i]])

# %%
df_state2.head()
# Out:
#             seq stateTime  decideCnt  clearCnt  examCnt  deathCnt  careCnt  \
# stateDt
# 2020-01-01    1     18:00        NaN       1.0      1.0       NaN      NaN
# 2020-02-02    2     09:00        2.0       2.0      2.0       2.0      NaN
# 2020-02-03    3     09:00       15.0       NaN      NaN       NaN      NaN
# 2020-02-04    4     00:00        NaN       NaN      NaN       NaN      NaN
# 2020-02-05    5     09:00       18.0       NaN    129.0       NaN      NaN
#
#             resutlNegCnt  accExamCnt  accExamCompCnt  accDefRate  \
# stateDt
# 2020-01-01           NaN         NaN             NaN         NaN
# 2020-02-02           NaN         NaN             NaN         NaN
# 2020-02-03           NaN         NaN             NaN         NaN
# 2020-02-04           NaN         NaN             NaN         NaN
# 2020-02-05           NaN         NaN             NaN         NaN
#
#                           createDt                updateDt
# stateDt
# 2020-01-01 2020-01-31 17:47:33.330  2020-02-03 12:21:56.56
# 2020-02-02 2020-02-03 12:22:49.490                     NaN
# 2020-02-03 2020-02-03 14:41:17.170  2020-02-04 14:19:46.46
# 2020-02-04 2020-02-03 21:26:59.590                     NaN
# 2020-02-05 2020-02-04 23:56:31.310   2020-02-05 9:43:16.16

# %%
#df.set_index([pd.Index([1, 2, 3, 4]), 'year'])
df_state2 = df_state2.reset_index(drop=False)
df_state2.head()
# Out:
#      stateDt  seq stateTime  decideCnt  clearCnt  examCnt  deathCnt  careCnt  \
# 0 2020-01-01    1     18:00        NaN       1.0      1.0       NaN      NaN
# 1 2020-02-02    2     09:00        2.0       2.0      2.0       2.0      NaN
# 2 2020-02-03    3     09:00       15.0       NaN      NaN       NaN      NaN
# 3 2020-02-04    4     00:00        NaN       NaN      NaN       NaN      NaN
# 4 2020-02-05    5     09:00       18.0       NaN    129.0       NaN      NaN
#
#    resutlNegCnt  accExamCnt  accExamCompCnt  accDefRate  \
# 0           NaN         NaN             NaN         NaN
# 1           NaN         NaN             NaN         NaN
# 2           NaN         NaN             NaN         NaN
# 3           NaN         NaN             NaN         NaN
# 4           NaN         NaN             NaN         NaN
#
#                  createDt                updateDt
# 0 2020-01-31 17:47:33.330  2020-02-03 12:21:56.56
# 1 2020-02-03 12:22:49.490                     NaN
# 2 2020-02-03 14:41:17.170  2020-02-04 14:19:46.46
# 3 2020-02-03 21:26:59.590                     NaN
# 4 2020-02-04 23:56:31.310   2020-02-05 9:43:16.16

# %%
df_state2 = df_state2.set_index("seq")

# %%
df_state2.head()
# Out:
#        stateDt stateTime  decideCnt  clearCnt  examCnt  deathCnt  careCnt  \
# seq
# 1   2020-01-01     18:00        NaN       1.0      1.0       NaN      NaN
# 2   2020-02-02     09:00        2.0       2.0      2.0       2.0      NaN
# 3   2020-02-03     09:00       15.0       NaN      NaN       NaN      NaN
# 4   2020-02-04     00:00        NaN       NaN      NaN       NaN      NaN
# 5   2020-02-05     09:00       18.0       NaN    129.0       NaN      NaN
#
#      resutlNegCnt  accExamCnt  accExamCompCnt  accDefRate  \
# seq
# 1             NaN         NaN             NaN         NaN
# 2             NaN         NaN             NaN         NaN
# 3             NaN         NaN             NaN         NaN
# 4             NaN         NaN             NaN         NaN
# 5             NaN         NaN             NaN         NaN
#
#                    createDt                updateDt
# seq
# 1   2020-01-31 17:47:33.330  2020-02-03 12:21:56.56
# 2   2020-02-03 12:22:49.490                     NaN
# 3   2020-02-03 14:41:17.170  2020-02-04 14:19:46.46
# 4   2020-02-03 21:26:59.590                     NaN
# 5   2020-02-04 23:56:31.310   2020-02-05 9:43:16.16

# %%
for s in sq:
#     print(s[0])
    df_state2.drop(index=[s[0]], inplace=True)

# %%
df_state2 = df_state2.reset_index(drop=False)
df_state2.head()
# Out:
#    seq    stateDt stateTime  decideCnt  clearCnt  examCnt  deathCnt  careCnt  \
# 0    1 2020-01-01     18:00        NaN       1.0      1.0       NaN      NaN
# 1    2 2020-02-02     09:00        2.0       2.0      2.0       2.0      NaN
# 2    3 2020-02-03     09:00       15.0       NaN      NaN       NaN      NaN
# 3    4 2020-02-04     00:00        NaN       NaN      NaN       NaN      NaN
# 4    5 2020-02-05     09:00       18.0       NaN    129.0       NaN      NaN
#
#    resutlNegCnt  accExamCnt  accExamCompCnt  accDefRate  \
# 0           NaN         NaN             NaN         NaN
# 1           NaN         NaN             NaN         NaN
# 2           NaN         NaN             NaN         NaN
# 3           NaN         NaN             NaN         NaN
# 4           NaN         NaN             NaN         NaN
#
#                  createDt                updateDt
# 0 2020-01-31 17:47:33.330  2020-02-03 12:21:56.56
# 1 2020-02-03 12:22:49.490                     NaN
# 2 2020-02-03 14:41:17.170  2020-02-04 14:19:46.46
# 3 2020-02-03 21:26:59.590                     NaN
# 4 2020-02-04 23:56:31.310   2020-02-05 9:43:16.16

# %%
df_state.shape
# Out:
# (399, 14)

# %%
df_state.head()
# Out:
#    seq    stateDt stateTime  decideCnt  clearCnt  examCnt  deathCnt  careCnt  \
# 0    1 2020-01-01     18:00        NaN       1.0      1.0       NaN      NaN
# 1    2 2020-02-02     09:00        2.0       2.0      2.0       2.0      NaN
# 2    3 2020-02-03     09:00       15.0       NaN      NaN       NaN      NaN
# 3    4 2020-02-04     00:00        NaN       NaN      NaN       NaN      NaN
# 4    5 2020-02-05     09:00       18.0       NaN    129.0       NaN      NaN
#
#    resutlNegCnt  accExamCnt  accExamCompCnt  accDefRate  \
# 0           NaN         NaN             NaN         NaN
# 1           NaN         NaN             NaN         NaN
# 2           NaN         NaN             NaN         NaN
# 3           NaN         NaN             NaN         NaN
# 4           NaN         NaN             NaN         NaN
#
#                  createDt                updateDt
# 0 2020-01-31 17:47:33.330  2020-02-03 12:21:56.56
# 1 2020-02-03 12:22:49.490                     NaN
# 2 2020-02-03 14:41:17.170  2020-02-04 14:19:46.46
# 3 2020-02-03 21:26:59.590                     NaN
# 4 2020-02-04 23:56:31.310   2020-02-05 9:43:16.16

# %%
df_state2.shape
# Out:
# (356, 14)

# %%
df_state2.stateDt.value_counts()
# Out:
# 2020-02-05    2
# 2020-02-21    2
# 2020-02-08    2
# 2020-10-29    1
# 2020-11-29    1
# 2020-04-29    1
# 2020-03-29    1
# 2020-02-27    1
# 2021-01-16    1
# 2020-12-16    1
# 2020-11-15    1
# 2020-09-28    1
# 2020-10-15    1
# 2020-09-14    1
# 2020-08-14    1
# 2020-08-05    1
# 2020-07-05    1
# 2020-06-04    1
# 2020-05-04    1
# 2020-04-03    1
# 2020-03-03    1
# 2020-01-01    1
# 2020-02-29    1
# 2020-12-18    1
# 2021-01-12    1
# 2020-12-29    1
# 2020-10-14    1
# 2020-09-13    1
# 2020-08-13    1
# 2020-07-13    1
# 2020-06-12    1
# 2020-05-12    1
# 2020-04-11    1
# 2020-03-11    1
# 2020-11-28    1
# 2020-12-15    1
# 2020-10-28    1
# 2020-09-27    1
# 2020-08-27    1
# 2020-07-27    1
# 2020-06-26    1
# 2020-05-26    1
# 2020-03-25    1
# 2020-02-23    1
# 2020-11-14    1
# 2021-01-15    1
# 2020-11-17    1
# 2021-01-01    1
# 2020-10-17    1
# 2020-09-16    1
# 2020-08-16    1
# 2020-07-16    1
# 2020-06-15    1
# 2020-05-15    1
# 2020-04-14    1
# 2020-03-14    1
# 2020-12-01    1
# 2020-02-26    1
# 2020-10-31    1
# 2020-09-30    1
# 2020-08-30    1
# 2020-07-30    1
# 2020-06-29    1
# 2020-05-29    1
# 2020-04-28    1
# 2020-03-28    1
# 2020-02-11    1
# Name: stateDt, dtype: int64

# %% [markdown]
# - 2020년 5일, 8일, 21일은 아직도 두 개씩 남아 있다. (index 4, 8, 17 제거 필요)

# %%
df_state2[df_state2.stateDt=="2020-02-05"]
# Out:
#    seq    stateDt stateTime  decideCnt  clearCnt  examCnt  deathCnt  careCnt  \
# 4    5 2020-02-05     09:00       18.0       NaN    129.0       NaN      NaN
# 5    6 2020-02-05     19:00       19.0       1.0     40.0       NaN      NaN
#
#    resutlNegCnt  accExamCnt  accExamCompCnt  accDefRate  \
# 4           NaN         NaN             NaN         NaN
# 5           NaN         NaN             NaN         NaN
#
#                  createDt                updateDt
# 4 2020-02-04 23:56:31.310   2020-02-05 9:43:16.16
# 5 2020-02-05 20:05:40.400  2020-02-06 10:05:36.36

# %%
df_state2[df_state2.stateDt=="2020-02-08"]
# Out:
#    seq    stateDt stateTime  decideCnt  clearCnt  examCnt  deathCnt  careCnt  \
# 8   13 2020-02-08     16:00       24.0       2.0    939.0       NaN      NaN
# 9   14 2020-02-08     16:00       24.0       2.0    939.0       NaN      NaN
#
#    resutlNegCnt  accExamCnt  accExamCompCnt  accDefRate  \
# 8           NaN         NaN             NaN         NaN
# 9           NaN         NaN             NaN         NaN
#
#                  createDt updateDt
# 8 2020-02-08 17:01:12.120      NaN
# 9 2020-02-08 17:01:34.340      NaN

# %%
df_state2[df_state2.stateDt=="2020-02-21"]
# Out:
#     seq    stateDt stateTime  decideCnt  clearCnt  examCnt  deathCnt  careCnt  \
# 17   41 2020-02-21     16:00      204.0      17.0   3180.0       1.0      NaN
# 18   42 2020-02-21     16:00      204.0      17.0   3180.0       1.0      NaN
#
#     resutlNegCnt  accExamCnt  accExamCompCnt  accDefRate  \
# 17           NaN         NaN             NaN         NaN
# 18           NaN         NaN             NaN         NaN
#
#                   createDt updateDt
# 17 2020-02-21 17:12:33.330      NaN
# 18 2020-02-21 17:13:21.210      NaN

# %%
df_state2.drop([4, 8, 17], inplace=True)

# %%
df_state2.shape
# Out:
# (353, 14)

# %% [markdown]
# - decideCnt(t)-decideCnt(t-1) : dailyCnt 로 생성
# - 그 전에 Nan값 처리부터.. (다행히 2개밖에 없다)

# %%
df_state2.isnull().sum()
# Out:
# seq                 0
# stateDt             0
# stateTime           0
# decideCnt           2
# clearCnt            2
# examCnt             2
# deathCnt           13
# careCnt            25
# resutlNegCnt       25
# accExamCnt         25
# accExamCompCnt     25
# accDefRate         25
# createDt            0
# updateDt          332
# dtype: int64

# %%
df_state3 = df_state2.dropna(subset=["decideCnt"])

# %%
df_state3.reset_index(inplace=True, drop=True)

# %%
df_state3.shape
# Out:
# (351, 14)

# %%
df_state3.head()
# Out:
#    seq    stateDt stateTime  decideCnt  clearCnt  examCnt  deathCnt  careCnt  \
# 0    2 2020-02-02     09:00        2.0       2.0      2.0       2.0      NaN
# 1    3 2020-02-03     09:00       15.0       NaN      NaN       NaN      NaN
# 2    6 2020-02-05     19:00       19.0       1.0     40.0       NaN      NaN
# 3    7 2020-02-06     09:00       23.0       1.0    169.0       NaN      NaN
# 4    9 2020-02-07     16:00       24.0       2.0    327.0       NaN      NaN
#
#    resutlNegCnt  accExamCnt  accExamCompCnt  accDefRate  \
# 0           NaN         NaN             NaN         NaN
# 1           NaN         NaN             NaN         NaN
# 2           NaN         NaN             NaN         NaN
# 3           NaN         NaN             NaN         NaN
# 4           NaN         NaN             NaN         NaN
#
#                  createDt                updateDt
# 0 2020-02-03 12:22:49.490                     NaN
# 1 2020-02-03 14:41:17.170  2020-02-04 14:19:46.46
# 2 2020-02-05 20:05:40.400  2020-02-06 10:05:36.36
# 3 2020-02-06 09:09:49.490  2020-02-06 10:04:35.35
# 4 2020-02-07 17:20:45.450                     NaN

# %%
dailyCnt = pd.Series(0, index=range(0,len(df_state3)))

# %%
for i in range(1, len(df_state3)):
    dailyCnt.iloc[i] = (df_state3.decideCnt.iloc[i] - df_state3.decideCnt.iloc[i-1])
print(i)
# Out:
# 350

# %%
dailyCnt[:5]
# Out:
# 0     0.0
# 1    13.0
# 2     4.0
# 3     4.0
# 4     1.0
# dtype: float64

# %%
df_state3.tail()
# Out:
#      seq    stateDt stateTime  decideCnt  clearCnt   examCnt  deathCnt  \
# 346  396 2021-01-24     00:00    75084.0   62530.0  135765.0    1349.0
# 347  397 2021-01-25     00:00    75521.0   62956.0  134549.0    1360.0
# 348  398 2021-01-26     00:00    75875.0   64793.0  138624.0    1371.0
# 349  399 2021-01-27     00:00    76429.0   65478.0  138427.0    1378.0
# 350  400 2021-01-28     00:00    76926.0   66016.0  139424.0    1386.0
#
#      careCnt  resutlNegCnt  accExamCnt  accExamCompCnt  accDefRate  \
# 346  11205.0     5143500.0   5354349.0       5218584.0    1.438781
# 347  11205.0     5166016.0   5376086.0       5241537.0    1.440818
# 348   9711.0     5208269.0   5422768.0       5284144.0    1.435900
# 349   9573.0     5254391.0   5469247.0       5330820.0    1.433719
# 350   9524.0     5305839.0   5522189.0       5382765.0    1.429117
#
#                    createDt updateDt
# 346 2021-01-24 09:31:28.637      NaN
# 347 2021-01-25 09:38:09.015      NaN
# 348 2021-01-26 09:41:15.083      NaN
# 349 2021-01-27 09:45:38.773      NaN
# 350 2021-01-28 09:38:09.595      NaN

# %%
dailyCnt[-5:]
# Out:
# 346    392.0
# 347    437.0
# 348    354.0
# 349    554.0
# 350    497.0
# dtype: float64

# %%
df_state3["dailyCnt"] = dailyCnt

# %%
df_state3.head()
# Out:
#    seq    stateDt stateTime  decideCnt  clearCnt  examCnt  deathCnt  careCnt  \
# 0    2 2020-02-02     09:00        2.0       2.0      2.0       2.0      NaN
# 1    3 2020-02-03     09:00       15.0       NaN      NaN       NaN      NaN
# 2    6 2020-02-05     19:00       19.0       1.0     40.0       NaN      NaN
# 3    7 2020-02-06     09:00       23.0       1.0    169.0       NaN      NaN
# 4    9 2020-02-07     16:00       24.0       2.0    327.0       NaN      NaN
#
#    resutlNegCnt  accExamCnt  accExamCompCnt  accDefRate  \
# 0           NaN         NaN             NaN         NaN
# 1           NaN         NaN             NaN         NaN
# 2           NaN         NaN             NaN         NaN
# 3           NaN         NaN             NaN         NaN
# 4           NaN         NaN             NaN         NaN
#
#                  createDt                updateDt  dailyCnt
# 0 2020-02-03 12:22:49.490                     NaN       0.0
# 1 2020-02-03 14:41:17.170  2020-02-04 14:19:46.46      13.0
# 2 2020-02-05 20:05:40.400  2020-02-06 10:05:36.36       4.0
# 3 2020-02-06 09:09:49.490  2020-02-06 10:04:35.35       4.0
# 4 2020-02-07 17:20:45.450                     NaN       1.0

# %% [markdown]
# - stateDt X decideCnt

# %%
fig, ax = plt.subplots(figsize=(16,8))
sns.set_theme(style="whitegrid")
sns.color_palette("Paired")
sns.lineplot(x='stateDt', y='dailyCnt', data=df_state3, ax=ax, linewidth=2.5)
# Out:
# <AxesSubplot:xlabel='stateDt', ylabel='dailyCnt'>

# %%
msno.matrix(df_state)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---

# %% [markdown]
# ## Covid19GenAgeCaseInf.csv
#
# 1. seq : 고유값
# 2. gubun : 구분
# 3. confCase : 확진자
# 4. confCaseRate : 확진률
# 5. death : 사망자
# 6. deathRate : 사망률
# 7. criticalRate : 치명률
# 8. createDt : 등록일시(시분초)
# 9. updateDt : 수정일시(시분초)

# %%
df_info = pd.read_csv("data_public/Covid19GenAgeCaseInf.csv")

# %%
df_info.shape
# Out:
# (3169, 9)

# %%
df_info.describe()
# Out:
#                seq      confCase  confCaseRate        death    deathRate  \
# count  3169.000000   3169.000000   3169.000000  2305.000000  3160.000000
# mean   3007.995267   4520.028716     18.176403   109.282863    18.228247
# std    1912.130774   5871.965656     16.342331   132.468454    21.387116
# min       1.000000      1.000000      1.000000     1.000000     0.000000
# 25%    1366.000000   1177.000000      5.740000    10.000000     0.000000
# 50%    2862.000000   2576.000000     13.100000    77.000000     5.180000
# 75%    4655.000000   5346.000000     19.270000   152.000000    46.890000
# max    6491.000000  38948.000000     60.100000   770.000000    56.770000
#
#        criticalRate  updateDt
# count   2305.000000       0.0
# mean       4.569796       NaN
# std        7.126969       NaN
# min        0.030000       NaN
# 25%        0.260000       NaN
# 50%        1.550000       NaN
# 75%        3.040000       NaN
# max       26.680000       NaN

# %%
df_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3169 entries, 0 to 3168
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   seq           3169 non-null   int64
#  1   gubun         3169 non-null   object
#  2   confCase      3169 non-null   int64
#  3   confCaseRate  3169 non-null   float64
#  4   death         2305 non-null   float64
#  5   deathRate     3160 non-null   float64
#  6   criticalRate  2305 non-null   float64
#  7   createDt      3169 non-null   object
#  8   updateDt      0 non-null      float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 222.9+ KB

# %%
df_info.head()
# Out:
#    seq  gubun  confCase  confCaseRate  death  deathRate  criticalRate  \
# 0    1     남성      3905         39.90   82.0      50.62          2.10
# 1    2     여성      5881         60.10   80.0      49.38          1.36
# 2    3  80 이상       442          4.52   82.0      50.62         18.55
# 3    4  70-79       651          6.65   46.0      28.40          7.07
# 4    5  60-69      1235         12.62   22.0      13.58          1.78
#
#                  createDt  updateDt
# 0  2020-04-02 19:02:48.48       NaN
# 1  2020-04-02 19:02:48.48       NaN
# 2  2020-04-02 19:02:48.48       NaN
# 3  2020-04-02 19:02:48.48       NaN
# 4  2020-04-02 19:02:48.48       NaN

# %%
df_info.tail()
# Out:
#        seq  gubun  confCase  confCaseRate  death  deathRate  criticalRate  \
# 3164  6487  40-49     10946         14.32   10.0       0.73          0.09
# 3165  6488  30-39      9765         12.78    6.0       0.44          0.06
# 3166  6489  20-29     11743         15.36    NaN       0.00           NaN
# 3167  6490  10-19      5051          6.61    NaN       0.00           NaN
# 3168  6491    0-9      2883          3.77    NaN       0.00           NaN
#
#                      createDt  updateDt
# 3164  2021-01-27 14:14:31.564       NaN
# 3165  2021-01-27 14:14:31.564       NaN
# 3166  2021-01-27 14:14:31.564       NaN
# 3167  2021-01-27 14:14:31.565       NaN
# 3168  2021-01-27 14:14:31.565       NaN

# %%
msno.matrix(df_info)
# Out:
# <AxesSubplot:>

# %%
df_info[df_info['gubun']=="남성"].head(20)
# Out:
#      seq gubun  confCase  confCaseRate  death  deathRate  criticalRate  \
# 0      1    남성      3905         39.90   82.0      50.62          2.10
# 11    12    남성      4138         40.05  101.0      52.60          2.44
# 23    24    남성      4163         40.09  106.0      53.00          2.55
# 34    35    남성      4163         40.09  106.0      53.00          2.55
# 45    46    남성      4163         40.09  106.0      53.00          2.55
# 56    58    남성      4163         40.09  106.0      53.00          2.55
# 67    69    남성      4163         40.09  106.0      53.00          2.55
# 78    80    남성      4185         40.15  107.0      52.45          2.56
# 89    91    남성      4200         40.19  109.0      52.40          2.60
# 100  102    남성      4215         40.22  111.0      52.61          2.63
# 111  113    남성      4229         40.23  113.0      52.80          2.67
# 122  124    남성      4243         40.27  115.0      53.00          2.71
# 133  135    남성      4256         40.29  116.0      52.25          2.73
# 144  146    남성      4266         40.28  118.0      52.44          2.77
# 155  157    남성      4272         40.25  122.0      53.28          2.86
# 166  168    남성      4272         40.25  122.0      53.28          2.86
# 177  179    남성      4286         40.30  122.0      53.04          2.85
# 188  190    남성      4293         40.30  124.0      53.45          2.89
# 199  201    남성      4297         40.31  124.0      52.99          2.89
# 210  212    남성      4297         40.31  124.0      52.99          2.89
#
#                    createDt  updateDt
# 0    2020-04-02 19:02:48.48       NaN
# 11   2020-04-07 19:32:08.08       NaN
# 23   2020-04-08 10:55:38.38       NaN
# 34   2020-04-08 10:56:57.57       NaN
# 45   2020-04-08 10:58:36.36       NaN
# 56   2020-04-08 11:33:25.25       NaN
# 67   2020-04-08 11:34:40.40       NaN
# 78   2020-04-09 10:23:55.55       NaN
# 89   2020-04-10 10:17:34.34       NaN
# 100  2020-04-11 10:29:51.51       NaN
# 111  2020-04-12 10:22:13.13       NaN
# 122  2020-04-13 10:22:30.30       NaN
# 133  2020-04-14 10:24:23.23       NaN
# 144  2020-04-15 15:44:18.18       NaN
# 155  2020-04-16 11:05:01.01       NaN
# 166  2020-04-16 16:10:09.09       NaN
# 177  2020-04-17 10:35:19.19       NaN
# 188  2020-04-18 10:45:43.43       NaN
# 199  2020-04-19 10:54:13.13       NaN
# 210  2020-04-19 11:07:32.32       NaN
